# %%
import pandas  as pd
df = pd.read_csv('people-100.csv')

# %%
df.head()  # Sort by Age column

# %%
df.sort_values(by='First Name', inplace=True) # Sort by 'First Name' column

# %%
df.sort_values(by='First Name', ascending=False, inplace=True) # Sort by 'First Name' column in descending order

# %%
df[df['Sex'] == 'Female', ]  # Filter rows where Sex is Female

# %%
df.query("Sex == 'Female'")  # Alternative filtering method

# %%
df.sample(5) # Random sample of 5 rows

# %%
df.filter(like='Name')  # Select columns with 'Name' in their title
# Out:
#    First Name Last Name
# 3     Yesenia  Martinez
# 93     Xavier      Cole
# 42     Willie      Vang
# 97     Wesley      Bray
# 73   Veronica    Briggs
# ..        ...       ...
# 47      Becky     Brady
# 81     Andrew    Waters
# 18      Alvin      Paul
# 90     Alison     Nixon
# 24     Alfred    Mcneil
#
# [100 rows x 2 columns]

# %%
df
# Out:
#     Index          User Id First Name Last Name     Sex  \
# 3       4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 93     94  d181FFB7d3E68bb     Xavier      Cole    Male
# 42     43  9edBC94aE7cA22a     Willie      Vang  Female
# 97     98  2fEc528aFAF0b69     Wesley      Bray    Male
# 73     74  dBfA17Aaf16b4ab   Veronica    Briggs  Female
# ..    ...              ...        ...       ...     ...
# 47     48  Ee4eB129dC7913A      Becky     Brady    Male
# 81     82  E1cB5cA8CA7CC0a     Andrew    Waters    Male
# 18     19  7F7E1BAcb0C9AFf      Alvin      Paul    Male
# 90     91  F0aeC9c2759F3C6     Alison     Nixon  Female
# 24     25  c5B09fb33e8bA0A     Alfred    Mcneil  Female
#
#                            Email                  Phone Date of birth  \
# 3      kaitlinkaiser@example.com           584.094.6111    2017-08-03
# 93         nicolas90@example.org             8164259975    1938-11-29
# 42      haleymathews@example.net       741.168.6854x067    1978-02-02
# ...

# %%
df.nlargest(5, 'Index')  # Top 5 oldest individuals
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
#
#                          Email                 Phone Date of birth  \
# 99       pcopeland@example.org   (341)594-6554x44657    2016-11-15
# 98  alexiscantrell@example.org  001-273-685-6932x092    2012-04-12
# 97        regina11@example.org    995-542-3004x76800    1994-12-28
# 96       latasha46@example.net      001-865-478-5157    1932-04-29
# 95         bmartin@example.org  001-095-524-2112x257    1954-07-30
#
#                 Job Title
# 99  IT sales professional
# 98   Broadcast journalist
# 97         Police officer
# 96              Barrister
# 95      Software engineer

# %%
df.nsmallest(5, 'Index')  # Top 5 youngest individuals
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon
